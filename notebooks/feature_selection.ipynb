# %% [markdown]
# # Feature selection
#
# Use this notebook to determine the most relevant features for our modelling work

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

# %%
from warehouse.spark import get_spark

spark = get_spark()

# %%
df = (
    spark.read
    .format("delta")
    .load("../data/delta/horse-prices")
)

# %%
df.limit(5).show()
